# %%
from Univariate import Univariate
import pandas as pd

df = pd.read_csv('Placement.csv')  # Replace 'your_data.csv' with your actual data file

obj = Univariate(df)

qunt, qual = obj.quanQual()

print(qunt)
print(qual)
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']
# list
