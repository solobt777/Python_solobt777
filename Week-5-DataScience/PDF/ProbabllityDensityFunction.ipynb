# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kidney_disease_Cleaned.csv')

df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
# use sns to plot displot for the 'age' column
sns.displot(df['cad'], kde=True)
plt.title('Probability Density Function of cad')
plt.xlabel('cad')
plt.ylabel('Density')
plt.show()
# Out:
# /Users/solomonrajkumar.sathianandaraj/Library/CloudStorage/OneDrive-McKessonCorporation/Documents/Solo_docs/INTO_United_States/Learning_Path/Hope_AI/Start_Course/Week_2_Python/myevn/lib/python3.13/site-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/solomonrajkumar.sathianandaraj/Library/CloudStorage/OneDrive-McKessonCorporation/Documents/Solo_docs/INTO_United_States/Learning_Path/Hope_AI/Start_Course/Week_2_Python/myevn/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
