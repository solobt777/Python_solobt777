# %% [markdown]
# <a href="https://colab.research.google.com/github/solobt777/Python_solobt777/blob/main/Week-3-Machine-Learning-Assignments/GridSearch_Assignment_without_trainNTest_split_N_normalization/SVM_gridsearch_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Gridsearch Assignment using SVM without train test split and without Normalization

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR # Support Vector Regression for continuous target variable
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hope AI by Ramisha/data/insurance_pre.csv')
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400     False        True
# 1   18  33.770         1   1725.55230      True       False
# 2   28  33.000         3   4449.46200      True       False
# 3   33  22.705         0  21984.47061      True       False
# 4   32  28.880         0   3866.85520      True       False

# %%
X = df.drop('charges', axis=1)
y = df['charges']  # Assuming 'Charges' is the target variable

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# Stage 1: Quick search with reduced grid
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
                'C':[100,1000,2000,3000]}

grid = GridSearchCV(SVR(), param_grid, cv=3, verbose=1, n_jobs=4)
# fitting the model for grid search
grid.fit(X, y)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=SVR(), n_jobs=4,
#              param_grid={'C': [100, 1000, 2000, 3000],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=1)

# %%
from sklearn.metrics import r2_score
# Predicting the Test set results

y_pred=grid.predict(X)
r2score = r2_score(y,y_pred)
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
re
print("The R_score value for best parameter {}:".format(grid.best_params_), r2score)
# Out:
# The R_score value for best parameter {'C': 2000, 'kernel': 'linear'}: 0.6790661970593859

# %%
# Stage 2: Fine-tune around best params
best_kernel = grid.best_params_['kernel']
param_grid_2 = {'kernel':[best_kernel],
                'C':[int(grid.best_params_['C']/2),
                     grid.best_params_['C'],
                     int(grid.best_params_['C']*2)],
                'gamma':['auto','scale']}

gs2 = GridSearchCV(SVR(), param_grid_2, cv=5, verbose=1, n_jobs=4)
gs2.fit(X, y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=4,
#              param_grid={'C': [1000, 2000, 4000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['linear']},
#              verbose=1)

# %%
from sklearn.metrics import r2_score
# Predicting the Test set results

y_pred=gs2.predict(X)
r2score = r2_score(y,y_pred)
# print best parameter after tuning
#print(grid.best_params_)
re=gs2.cv_results_
re
print("The R_score value for best parameter {}:".format(gs2.best_params_), r2score)
# Out:
# The R_score value for best parameter {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}: 0.7179049746029832
